# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
KD_Overral = pd.read_csv("../KD/PREDICTION/KD_PREDICTION_Universal_v2_Overral.csv")
KD_Seen    = pd.read_csv("../KD/PREDICTION/KD_PREDICTION_Universal_v2_Seen.csv")
KD_Unseen  = pd.read_csv("../KD/PREDICTION/KD_PREDICTION_Universal_v2_Unseen.csv")

# %%
epiTCR_Overral = pd.read_csv("../epiTCR/PREDICTION/epiTCR_PREDICTION_Universal_v2_Overral.csv")
epiTCR_Seen    = pd.read_csv("../epiTCR/PREDICTION/epiTCR_PREDICTION_Universal_v2_Seen.csv")
epiTCR_Unseen  = pd.read_csv("../epiTCR/PREDICTION/epiTCR_PREDICTION_Universal_v2_Unseen.csv")

# %%
TEIM_Overral = pd.read_csv("../TEIM/PREDICTION/TEIM_PREDICTION_Universal_v2_Overral.csv")
TEIM_Seen    = pd.read_csv("../TEIM/PREDICTION/TEIM_PREDICTION_Universal_v2_Seen.csv")
TEIM_Unseen  = pd.read_csv("../TEIM/PREDICTION/TEIM_PREDICTION_Universal_v2_Unseen.csv")

# %%
TEInet_Overral = pd.read_csv("../TEINet/PREDICTION/TEInet_PREDICTION_Universal_v2_Overral.csv")
TEInet_Seen    = pd.read_csv("../TEINet/PREDICTION/TEInet_PREDICTION_Universal_v2_Seen.csv")
TEInet_Unseen  = pd.read_csv("../TEINet/PREDICTION/TEInet_PREDICTION_Universal_v2_Unseen.csv")

# %%
Bertrand_Overral = pd.read_csv("../BERTrand/PREDICTION/Bertrand_PREDICTION_Universal_v2_Overral.csv")
Bertrand_Seen    = pd.read_csv("../BERTrand/PREDICTION/Bertrand_PREDICTION_Universal_v2_Seen.csv")
Bertrand_Unseen  = pd.read_csv("../BERTrand/PREDICTION/Bertrand_PREDICTION_Universal_v2_Unseen.csv")

# %%
NetTCR_Overral = pd.read_csv("../NetTCR/PREDICTION/NetTCR_PREDICTION_Universal_v2_Overral.csv")
NetTCR_Seen    = pd.read_csv("../NetTCR/PREDICTION/NetTCR_PREDICTION_Universal_v2_Seen.csv")
NetTCR_Unseen  = pd.read_csv("../NetTCR/PREDICTION/NetTCR_PREDICTION_Universal_v2_Unseen.csv")

# %%
KD_Dominant  = pd.read_csv("../KD/PREDICTION/KD_PREDICTION_Universal_v2_Dominant.csv")
KD_NoDominant  = pd.read_csv("../KD/PREDICTION/KD_PREDICTION_Universal_v2_NoDominant.csv")

# %%
epiTCR_Dominant  = pd.read_csv("../epiTCR/PREDICTION/epiTCR_PREDICTION_Universal_v2_Dominant.csv")
epiTCR_NoDominant  = pd.read_csv("../epiTCR/PREDICTION/epiTCR_PREDICTION_Universal_v2_NoDominant.csv")

# %%
TEIM_Dominant  = pd.read_csv("../TEIM/PREDICTION/TEIM_PREDICTION_Universal_v2_Dominant.csv")
TEIM_NoDominant  = pd.read_csv("../TEIM/PREDICTION/TEIM_PREDICTION_Universal_v2_NoDominant.csv")

NetTCR_Dominant  = pd.read_csv("../NetTCR/PREDICTION/NetTCR_PREDICTION_Universal_v2_Dominant.csv")
NetTCR_NoDominant  = pd.read_csv("../NetTCR/PREDICTION/NetTCR_PREDICTION_Universal_v2_NoDominant.csv")

TEInet_Dominant  = pd.read_csv("../TEINet/PREDICTION/TEInet_PREDICTION_Universal_v2_Dominant.csv")
TEInet_NoDominant  = pd.read_csv("../TEINet/PREDICTION/TEInet_PREDICTION_Universal_v2_NoDominant.csv")

BERTrand_Dominant  = pd.read_csv("../BERTrand/PREDICTION/BERTrand_PREDICTION_Universal_v2_Dominant.csv")
BERTrand_NoDominant  = pd.read_csv("../BERTrand/PREDICTION/BERTrand_PREDICTION_Universal_v2_NoDominant.csv")

# %%
KD_NOTGEN = KD_Overral[KD_Overral.epitope.isin(LST_PEP_NOTGEN)]
epiTCR_NOTGEN = epiTCR_Overral[epiTCR_Overral.epitope.isin(LST_PEP_NOTGEN)]
TEIM_NOTGEN = TEIM_Overral[TEIM_Overral.epitope.isin(LST_PEP_NOTGEN)]
TEInet_NOTGEN = TEInet_Overral[TEInet_Overral.epitope.isin(LST_PEP_NOTGEN)]
Bertrand_NOTGEN = Bertrand_Overral[Bertrand_Overral.peptide_seq.isin(LST_PEP_NOTGEN)]

# %%
NetTCR_Overral
# Out:
#                 CDR3b      peptide              src  binder  prediction  \
# 0          AASSYGQNFV    QIKVRVDMV  tbadb_collected       1    0.000150
# 1           AIRAGGDEQ    HSKKKCDEL  tbadb_collected       1    0.852911
# 2           AISETDKLG    HSKKKCDEL  tbadb_collected       1    0.000797
# 3          ASIPNLGNEQ    LPPIVAKEI  tbadb_collected       1    1.000000
# 4         ASRDGQGHEQY    LPPIVAKEI  tbadb_collected       1    1.000000
# ...               ...          ...              ...     ...         ...
# 1366980  SARDRVRTDTQY     YSDLFRSL       znc23_gswt       0    0.001038
# 1366981  SARDRVRTDTQY    QTPLQFTHL       znc22_gswt       0    0.000132
# 1366982  SARDRVRTDTQY  RSGSRDSTPSR       znc22_gswt       0    0.000002
# 1366983  SARDRVRTDTQY   RQPEDTWAAL       znc21_gswt       0    0.000029
# 1366984  SARDRVRTDTQY   SPSQPRKKIF       znc24_gswt       0    0.000031
#
#          binder_pred
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 1366980            0
# 1366981            0
# 1366982            0
# 1366983            0
# 1366984            0
#
# [1366985 rows x 6 columns]

# %%
data_nettcr
# Out:
#                 CDR3b      peptide              src  binder  prediction  \
# 0          AASSYGQNFV    QIKVRVDMV  tbadb_collected       1    0.000150
# 1           AIRAGGDEQ    HSKKKCDEL  tbadb_collected       1    0.852911
# 2           AISETDKLG    HSKKKCDEL  tbadb_collected       1    0.000797
# 3          ASIPNLGNEQ    LPPIVAKEI  tbadb_collected       1    1.000000
# 4         ASRDGQGHEQY    LPPIVAKEI  tbadb_collected       1    1.000000
# ...               ...          ...              ...     ...         ...
# 1366980  SARDRVRTDTQY     YSDLFRSL       znc23_gswt       0    0.001038
# 1366981  SARDRVRTDTQY    QTPLQFTHL       znc22_gswt       0    0.000132
# 1366982  SARDRVRTDTQY  RSGSRDSTPSR       znc22_gswt       0    0.000002
# 1366983  SARDRVRTDTQY   RQPEDTWAAL       znc21_gswt       0    0.000029
# 1366984  SARDRVRTDTQY   SPSQPRKKIF       znc24_gswt       0    0.000031
#
#          binder_pred
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 1366980            0
# 1366981            0
# 1366982            0
# 1366983            0
# 1366984            0
#
# [1366985 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_Overral.copy()
data_epitcr = epiTCR_Overral.copy()
data_teim = TEIM_Overral.copy()
data_bertrand = Bertrand_Overral.copy()
data_teinet = TEInet_Overral.copy()
data_nettcr = NetTCR_Overral.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
roc_auc_teim = auc(fpr_teim, tpr_teim)

fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

fpr_nettcr, tpr_netctr, thresholds_nettcr = roc_curve(data_nettcr['binder'], data_nettcr['prediction'])
roc_auc_nettcr = auc(fpr_nettcr, tpr_netctr)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
plt.plot(fpr_nettcr, tpr_netctr, color='#B0578D', lw=2, label='NetTCR (AUC = {:.3f})'.format(roc_auc_nettcr))
plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction on Overral epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_Overral.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_Unseen.copy()
data_epitcr = epiTCR_Unseen.copy()
data_teim = TEIM_Unseen.copy()
data_bertrand = Bertrand_Unseen.copy()
data_teinet = TEInet_Unseen.copy()
data_teinet = TEInet_Unseen.copy()
data_nettcr = NetTCR_Unseen.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
roc_auc_teim = auc(fpr_teim, tpr_teim)

fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

fpr_nettcr, tpr_netctr, thresholds_nettcr = roc_curve(data_nettcr['binder'], data_nettcr['prediction'])
roc_auc_nettcr = auc(fpr_nettcr, tpr_netctr)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
plt.plot(fpr_nettcr, tpr_netctr, color='#B0578D', lw=2, label='NetTCR (AUC = {:.3f})'.format(roc_auc_nettcr))
plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction on Unseen epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_Unseen.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_NoDominant.copy()
data_epitcr = epiTCR_NoDominant.copy()
# data_teim = TEIM_Overral.copy()
# data_bertrand = Bertrand_Overral.copy()
# data_teinet = TEInet_Overral.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

# fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
# roc_auc_teim = auc(fpr_teim, tpr_teim)

# fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
# roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

# fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
# roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
# plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
# plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
# plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction Non-Dominant epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_NonDominant.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_NoDominant.copy()
data_epitcr = epiTCR_NoDominant.copy()
data_teim = TEIM_NoDominant.copy()
data_bertrand = BERTrand_NoDominant.copy()
data_teinet = TEInet_NoDominant.copy()
data_teinet = TEInet_NoDominant.copy()
data_nettcr = NetTCR_NoDominant.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
roc_auc_teim = auc(fpr_teim, tpr_teim)

fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

fpr_nettcr, tpr_netctr, thresholds_nettcr = roc_curve(data_nettcr['binder'], data_nettcr['prediction'])
roc_auc_nettcr = auc(fpr_nettcr, tpr_netctr)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
plt.plot(fpr_nettcr, tpr_netctr, color='#B0578D', lw=2, label='NetTCR (AUC = {:.3f})'.format(roc_auc_nettcr))
plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction on Overral epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_NonDominant2.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_NOTGEN.copy()
data_epitcr = epiTCR_NOTGEN.copy()
data_teim = TEIM_NOTGEN.copy()
data_bertrand = Bertrand_NOTGEN.copy()
data_teinet = TEInet_NOTGEN.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
roc_auc_teim = auc(fpr_teim, tpr_teim)

fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction on Overral epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_NOTGEN.png", bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Only 1 dominant ????

# Đọc dữ liệu từ hai DataFrame khác nhau
data_kd = KD_Dominant.copy()
data_epitcr = epiTCR_Dominant.copy()
data_teim = TEIM_Dominant.copy()
data_bertrand = BERTrand_Dominant.copy()
data_teinet = TEInet_Dominant.copy()

fpr_kd, tpr_kd, thresholds_kd = roc_curve(data_kd['binder'], data_kd['proba_pred'])
roc_auc_kd = auc(fpr_kd, tpr_kd)

fpr_epitcr, tpr_epitcr, thresholds_epitcr = roc_curve(data_epitcr['binder'], data_epitcr['predict_proba'])
roc_auc_epitcr = auc(fpr_epitcr, tpr_epitcr)

fpr_teim, tpr_teim, thresholds_teim = roc_curve(data_teim['binder'], data_teim['binding'])
roc_auc_teim = auc(fpr_teim, tpr_teim)

fpr_teinet, tpr_teinet, thresholds_teinet = roc_curve(data_teinet['binder'], data_teinet['expit_prediction'])
roc_auc_teinet = auc(fpr_teinet, tpr_teinet)

fpr_bertrand, tpr_bertrand, thresholds_bertrand = roc_curve(data_bertrand['binder'], data_bertrand['prediction'])
roc_auc_bertrand = auc(fpr_bertrand, tpr_bertrand)

# Vẽ ROC curve cho cả hai DataFrame
plt.figure(figsize=(8, 6))

plt.plot(fpr_kd, tpr_kd, color='#EF6262', lw=2, label='KD (AUC = {:.3f})'.format(roc_auc_kd))
plt.plot(fpr_epitcr, tpr_epitcr, color='#F3AA60', lw=2, label='epiTCR (AUC = {:.3f})'.format(roc_auc_epitcr))
plt.plot(fpr_teim, tpr_teim, color='#468B97', lw=2, label='TEIM (AUC = {:.3f})'.format(roc_auc_teim))
plt.plot(fpr_teinet, tpr_teinet, color='#B5CB99', lw=2, label='TEInet (AUC = {:.3f})'.format(roc_auc_teinet))
plt.plot(fpr_bertrand, tpr_bertrand, color='#B4B4B3', lw=2, label='Bertrand (AUC = {:.3f})'.format(roc_auc_bertrand))

plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Prediction on Dominant epitopes')
plt.legend(loc="lower right")

plt.savefig("./plots/AUC_Dominant2.png", bbox_inches='tight', dpi=300)
plt.show()
